# %% [markdown]
# <a href="https://colab.research.google.com/github/Zhongbingqin/Traffic-Sign-Recognition-Using-YOLOv5/blob/main/run_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
# %cd drive/My\ Drive/TSD_project_YOLOv5/yolov5
# Out:
# /content/drive/My Drive/TSD_project_YOLOv5/yolov5

# %%
# !pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 645kB 18.1MB/s

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data ./data/traffic_signs.yaml --cfg ./models/traffic_sign_yolov5x.yaml --weights ''

# %%
# !python3 detect.py --source inference/images/test_s.mov --device 0 --weight runs/exp4/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='0', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='inference/images/test_s.mov', update=False, view_img=False, weights=['runs/exp4/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# Fusing layers...
# Model Summary: 140 layers, 7.2627e+06 parameters, 6.61683e+06 gradients
# video 1/1 (1/2074) /content/drive/My Drive/TSD_project_YOLOv5/yolov5/inference/images/test_s.mov: 384x640 2 stops, Done. (0.071s)
# video 1/1 (2/2074) /content/drive/My Drive/TSD_project_YOLOv5/yolov5/inference/images/test_s.mov: 384x640 2 stops, Done. (0.013s)
# video 1/1 (3/2074) /content/drive/My Drive/TSD_project_YOLOv5/yolov5/inference/images/test_s.mov: 384x640 2 stops, Done. (0.012s)
# video 1/1 (4/2074) /content/drive/My Drive/TSD_project_YOLOv5/yolov5/inference/images/test_s.mov: 384x640 2 stops, Done. (0.012s)
# ...
